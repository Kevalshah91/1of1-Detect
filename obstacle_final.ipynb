# %%
import cv2
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model_path = "/Users/admin/Workspace/Cycle/models/yolo_v8m.pt"
model = YOLO(model_path)

# %%
image_path = "/Users/admin/Workspace/Cycle/images/pothole.png"  # Change this to your image path
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for Matplotlib

results = model(image)

# Draw detections on the image
for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
        conf = box.conf[0].item()  # Confidence score
        cls = int(box.cls[0].item())  # Class ID
        label = f"{model.names[cls]}: {conf:.2f}"  # Label with confidence

        # Draw bounding box and label
        cv2.rectangle(image_rgb, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image_rgb, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Show the output image using Matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(image_rgb)
plt.axis("off")  # Hide axes
plt.show()
# Out:
# 0: 448x640 10 Potholes, 152.1ms
# Speed: 3.0ms preprocess, 152.1ms inference, 4.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
model_path1="models/barricades.pt"
model1 = YOLO(model_path1)

# %%
image_path1 = "images/barrier.png"  # Change this to your image path
image1= cv2.imread(image_path1)
image_rgb1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for Matplotlib

results1= model1(image1)

# Draw detections on the image
for result in results1:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
        conf = box.conf[0].item()  # Confidence score
        cls = int(box.cls[0].item())  # Class ID
        label = f"{model1.names[cls]}: {conf:.2f}"  # Label with confidence

        # Draw bounding box and label
        cv2.rectangle(image_rgb1, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image_rgb1, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Show the output image using Matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(image_rgb1)
plt.axis("off")  # Hide axes
plt.show()
# Out:
# 0: 640x480 2 barricades, 33.6ms
# Speed: 1.3ms preprocess, 33.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 480)

# %%
image_path1 = "images/barricade.png"  # Change this to your image path
image1= cv2.imread(image_path1)
image_rgb1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for Matplotlib

results1= model1(image1)

# Draw detections on the image
for result in results1:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
        conf = box.conf[0].item()  # Confidence score
        cls = int(box.cls[0].item())  # Class ID
        label = f"{model1.names[cls]}: {conf:.2f}"  # Label with confidence

        # Draw bounding box and label
        cv2.rectangle(image_rgb1, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image_rgb1, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Show the output image using Matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(image_rgb1)
plt.axis("off")  # Hide axes
plt.show()
# Out:
# 0: 640x480 1 barricade, 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 480)
