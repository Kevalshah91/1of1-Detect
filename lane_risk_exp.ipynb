# %%
# !pip install -q ultralytics opencv-python numpy torch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.6/914.6 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 54.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 48.7 MB/s eta 0:00:00

# %%
import cv2
import numpy as np
import math
import time
from ultralytics import YOLO
from collections import deque
from concurrent.futures import ThreadPoolExecutor

class LaneDetector:
    def __init__(self):
        self.prev_left_line = None
        self.prev_right_line = None
        # Store last N frames of lane positions for smoothing
        self.left_lines_history = deque(maxlen=5)
        self.right_lines_history = deque(maxlen=5)

    def preprocess_image(self, image):
        # Convert to HSV for better lane marking detection
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # Create mask for white and yellow lane markings
        lower_white = np.array([0, 0, 200])
        upper_white = np.array([180, 30, 255])
        white_mask = cv2.inRange(hsv, lower_white, upper_white)

        lower_yellow = np.array([20, 100, 100])
        upper_yellow = np.array([30, 255, 255])
        yellow_mask = cv2.inRange(hsv, lower_yellow, upper_yellow)

        # Combine masks
        combined_mask = cv2.bitwise_or(white_mask, yellow_mask)

        # Apply slight Gaussian blur to reduce noise
        blurred = cv2.GaussianBlur(combined_mask, (5, 5), 0)

        return blurred

    def detect_lane(self, image):
        height, width = image.shape[:2]

        # Preprocess image
        processed = self.preprocess_image(image)

        # Apply Canny edge detection
        edges = cv2.Canny(processed, 50, 150)

        # Define ROI - focus on bottom half but consider wider area for cyclist view
        roi_vertices = np.array([
            [(0, height),
             (width * 0.35, height * 0.5),
             (width * 0.65, height * 0.5),
             (width, height)]
        ], dtype=np.int32)

        # Create and apply ROI mask
        mask = np.zeros_like(edges)
        cv2.fillPoly(mask, roi_vertices, 255)
        masked_edges = cv2.bitwise_and(edges, mask)

        # Detect lines using probabilistic Hough transform
        lines = cv2.HoughLinesP(
            masked_edges,
            rho=1,
            theta=np.pi/180,
            threshold=20,
            minLineLength=30,
            maxLineGap=50
        )

        left_lines, right_lines = [], []
        if lines is not None:
            for line in lines:
                x1, y1, x2, y2 = line[0]
                if x2 - x1 == 0:
                    continue

                slope = (y2 - y1) / (x2 - x1)
                length = np.sqrt((x2 - x1)**2 + (y2 - y1)**2)

                # Filter lines based on slope and length
                if abs(slope) < 0.3 or abs(slope) > 2.0:
                    continue

                if slope < 0:
                    left_lines.append(line[0])
                else:
                    right_lines.append(line[0])

        # Process detected lines
        left_line = self._process_lines(left_lines, height, True)
        right_line = self._process_lines(right_lines, height, False)

        # Update line history
        if left_line is not None:
            self.left_lines_history.append(left_line)
        if right_line is not None:
            self.right_lines_history.append(right_line)

        # Get smoothed lines
        left_line = self._get_smoothed_line(self.left_lines_history)
        right_line = self._get_smoothed_line(self.right_lines_history)

        # Calculate lane center and width
        lane_center = width // 2
        lane_width = width // 2  # Default value

        if left_line is not None and right_line is not None:
            # Calculate at bottom of frame
            lane_center = (left_line[0] + right_line[0]) // 2
            lane_width = right_line[0] - left_line[0]

        return lane_center, lane_width, left_line, right_line

    def _process_lines(self, lines, height, is_left):
        if not lines:
            return self.prev_left_line if is_left else self.prev_right_line

        # Convert lines to points for polynomial fitting
        points = np.array([(x1, y1) for x1, y1, x2, y2 in lines] +
                         [(x2, y2) for x1, y1, x2, y2 in lines])

        # Fit polynomial
        coeffs = np.polyfit(points[:, 1], points[:, 0], deg=1)

        # Generate line points
        y_bottom = height
        y_top = int(height * 0.5)
        x_bottom = int(coeffs[0] * y_bottom + coeffs[1])
        x_top = int(coeffs[0] * y_top + coeffs[1])

        line = [x_bottom, y_bottom, x_top, y_top]

        # Update previous line
        if is_left:
            self.prev_left_line = line
        else:
            self.prev_right_line = line

        return line

    def _get_smoothed_line(self, line_history):
        if not line_history:
            return None
        return np.mean(list(line_history), axis=0, dtype=np.int32)

class RiskAssessor:
    def __init__(self):
        self.vehicle_history = {}  # Store vehicle tracking history
        self.risk_threshold_close = 50  # pixels
        self.risk_threshold_speed = 15  # pixels per frame

    def calculate_risk(self, vehicle_data, lane_center, lane_width, frame_time):
        vehicle_id = vehicle_data['id']
        vehicle_x = vehicle_data['center_x']
        vehicle_y = vehicle_data['center_y']

        # Get vehicle history
        if vehicle_id in self.vehicle_history:
            prev_data = self.vehicle_history[vehicle_id]
            dx = vehicle_x - prev_data['x']
            dy = vehicle_y - prev_data['y']
            dt = frame_time - prev_data['time']

            # Calculate metrics
            speed = np.sqrt(dx**2 + dy**2) / dt if dt > 0 else 0
            lane_distance = abs(vehicle_x - lane_center)
            in_cyclist_lane = abs(vehicle_x - lane_center) < (lane_width * 0.4)

            # Risk factors
            risk_factors = {
                'speed': min(1.0, speed / self.risk_threshold_speed),
                'proximity': min(1.0, (lane_width - lane_distance) / self.risk_threshold_close),
                'lane_invasion': 1.0 if in_cyclist_lane else 0.0
            }

            # Calculate overall risk
            risk_score = (
                risk_factors['speed'] * 0.4 +
                risk_factors['proximity'] * 0.3 +
                risk_factors['lane_invasion'] * 0.3
            )

            risk_level = "SAFE"
            if risk_score > 0.7:
                risk_level = "DANGER"
            elif risk_score > 0.4:
                risk_level = "WARNING"

            # Additional danger checks
            if in_cyclist_lane and speed > self.risk_threshold_speed * 0.8:
                risk_level = "DANGER"

        else:
            risk_level = "SAFE"
            speed = 0

        # Update history
        self.vehicle_history[vehicle_id] = {
            'x': vehicle_x,
            'y': vehicle_y,
            'time': frame_time
        }

        return risk_level, speed

def process_video(input_path, output_path):
    # Initialize components
    model = YOLO('yolov8n.pt')
    lane_detector = LaneDetector()
    risk_assessor = RiskAssessor()
    target_classes = [2, 3, 5, 7, 1]  # car, motorcycle, bus, truck, bicycle

    cap = cv2.VideoCapture(input_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, fps, (1280, 720))

    frame_count = 0

    with ThreadPoolExecutor(max_workers=2) as executor:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame_count += 1
            frame_time = time.time()

            # Resize frame
            resized_frame = cv2.resize(frame, (1280, 720))

            # Process lane detection and YOLO detection concurrently
            lane_future = executor.submit(lane_detector.detect_lane, resized_frame)
            yolo_future = executor.submit(model, resized_frame)

            # Get results
            lane_center, lane_width, left_line, right_line = lane_future.result()
            results = yolo_future.result()

            # Draw lane overlay
            if left_line is not None and right_line is not None:
                overlay = resized_frame.copy()
                cv2.fillPoly(overlay, [np.array([
                    [left_line[0], left_line[1]],
                    [left_line[2], left_line[3]],
                    [right_line[2], right_line[3]],
                    [right_line[0], right_line[1]]
                ])], (0, 255, 0, 128))
                cv2.addWeighted(overlay, 0.35, resized_frame, 0.65, 0, resized_frame)

            # Process detections
            for result in results:
                boxes = result.boxes
                for box in boxes:
                    cls = int(box.cls[0])
                    conf = float(box.conf[0])

                    if cls in target_classes and conf >= 0.5:
                        x1, y1, x2, y2 = map(int, box.xyxy[0])

                        vehicle_data = {
                            'id': f"{cls}_{x1}_{y1}",
                            'center_x': (x1 + x2) // 2,
                            'center_y': (y1 + y2) // 2
                        }

                        risk_level, speed = risk_assessor.calculate_risk(
                            vehicle_data, lane_center, lane_width, frame_time
                        )

                        color = {
                            "SAFE": (0, 255, 0),
                            "WARNING": (0, 255, 255),
                            "DANGER": (0, 0, 255)
                        }[risk_level]

                        class_name = result.names[cls]
                        label = f'{class_name} {conf:.2f} | Risk: {risk_level} | Speed: {speed:.1f}'

                        cv2.rectangle(resized_frame, (x1, y1), (x2, y2), color, 2)
                        cv2.putText(resized_frame, label, (x1, y1 - 10),
                                  cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            # Write frame
            out.write(resized_frame)

            if frame_count % 30 == 0:
                fps_calc = 30 / (time.time() - frame_time)
                print(f"FPS: {fps_calc:.2f}")

    cap.release()
    out.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    input_path = '/content/lane.mp4'
    output_path = 'exp3.mp4'
    process_video(input_path, output_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# Speed: 3.4ms preprocess, 140.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 228.1ms
# Speed: 3.3ms preprocess, 228.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 228.2ms
# Speed: 3.1ms preprocess, 228.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 224.9ms
# Speed: 3.4ms preprocess, 224.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 226.6ms
# Speed: 3.1ms preprocess, 226.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 239.3ms
# Speed: 5.7ms preprocess, 239.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 224.2ms
# Speed: 3.2ms preprocess, 224.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 213.6ms
# Speed: 3.1ms preprocess, 213.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 239.9ms
# Speed: 3.2ms preprocess, 239.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 218.6ms
# Speed: 3.3ms preprocess, 218.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 228.7ms
# Speed: 3.6ms preprocess, 228.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 227.6ms
# Speed: 3.3ms preprocess, 227.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 223.0ms
# Speed: 7.5ms preprocess, 223.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 173.5ms
# Speed: 5.7ms preprocess, 173.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 144.6ms
# Speed: 3.2ms preprocess, 144.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 143.8ms
# Speed: 3.3ms preprocess, 143.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 141.5ms
# Speed: 3.2ms preprocess, 141.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 148.0ms
# Speed: 3.2ms preprocess, 148.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 167.80
#
# 0: 384x640 3 cars, 2 trucks, 145.9ms
# Speed: 3.8ms preprocess, 145.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 166.8ms
# Speed: 3.1ms preprocess, 166.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 148.6ms
# Speed: 3.3ms preprocess, 148.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 143.0ms
# Speed: 3.3ms preprocess, 143.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 145.1ms
# Speed: 3.4ms preprocess, 145.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 161.1ms
# Speed: 3.1ms preprocess, 161.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 148.7ms
# Speed: 3.2ms preprocess, 148.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 143.2ms
# Speed: 3.2ms preprocess, 143.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 146.1ms
# Speed: 3.2ms preprocess, 146.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 146.9ms
# Speed: 3.2ms preprocess, 146.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 141.6ms
# Speed: 10.1ms preprocess, 141.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 151.6ms
# Speed: 3.2ms preprocess, 151.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 157.2ms
# Speed: 3.2ms preprocess, 157.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 144.1ms
# Speed: 3.2ms preprocess, 144.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 137.8ms
# Speed: 7.0ms preprocess, 137.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 143.0ms
# Speed: 3.2ms preprocess, 143.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 152.0ms
# Speed: 3.2ms preprocess, 152.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 139.7ms
# Speed: 7.4ms preprocess, 139.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 156.1ms
# Speed: 3.4ms preprocess, 156.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 146.8ms
# Speed: 3.3ms preprocess, 146.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 142.9ms
# Speed: 3.2ms preprocess, 142.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 143.2ms
# Speed: 3.5ms preprocess, 143.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 155.4ms
# Speed: 3.2ms preprocess, 155.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 142.3ms
# Speed: 3.3ms preprocess, 142.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 156.0ms
# Speed: 3.4ms preprocess, 156.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 141.8ms
# Speed: 3.3ms preprocess, 141.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 148.6ms
# Speed: 3.2ms preprocess, 148.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 152.2ms
# Speed: 3.4ms preprocess, 152.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 146.5ms
# Speed: 3.4ms preprocess, 146.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 143.0ms
# Speed: 3.1ms preprocess, 143.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 173.75
#
# 0: 384x640 3 cars, 2 trucks, 151.5ms
# Speed: 3.2ms preprocess, 151.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 142.5ms
# Speed: 3.2ms preprocess, 142.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 140.7ms
# Speed: 4.5ms preprocess, 140.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 151.5ms
# Speed: 9.5ms preprocess, 151.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 147.6ms
# Speed: 3.1ms preprocess, 147.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 153.4ms
# Speed: 3.1ms preprocess, 153.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 151.1ms
# Speed: 3.2ms preprocess, 151.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 138.7ms
# Speed: 3.1ms preprocess, 138.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 144.1ms
# Speed: 3.5ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 150.0ms
# Speed: 3.2ms preprocess, 150.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 141.5ms
# Speed: 3.2ms preprocess, 141.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 157.5ms
# Speed: 3.2ms preprocess, 157.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 142.2ms
# Speed: 3.6ms preprocess, 142.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 142.5ms
# Speed: 3.2ms preprocess, 142.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 156.3ms
# Speed: 3.5ms preprocess, 156.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 140.4ms
# Speed: 3.2ms preprocess, 140.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 143.4ms
# Speed: 3.4ms preprocess, 143.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 154.4ms
# Speed: 3.4ms preprocess, 154.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 143.5ms
# Speed: 3.1ms preprocess, 143.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 143.0ms
# Speed: 3.1ms preprocess, 143.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 153.7ms
# Speed: 4.0ms preprocess, 153.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 210.7ms
# Speed: 3.3ms preprocess, 210.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 230.0ms
# Speed: 3.1ms preprocess, 230.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 230.4ms
# Speed: 3.3ms preprocess, 230.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 221.4ms
# Speed: 3.7ms preprocess, 221.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 211.1ms
# Speed: 2.9ms preprocess, 211.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 231.2ms
# Speed: 3.5ms preprocess, 231.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 219.9ms
# Speed: 5.1ms preprocess, 219.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 215.6ms
# Speed: 3.2ms preprocess, 215.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 222.7ms
# Speed: 4.7ms preprocess, 222.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 113.36
#
# 0: 384x640 3 cars, 2 trucks, 238.5ms
# Speed: 5.4ms preprocess, 238.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 254.0ms
# Speed: 3.2ms preprocess, 254.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 194.9ms
# Speed: 3.3ms preprocess, 194.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 143.1ms
# Speed: 3.2ms preprocess, 143.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 149.3ms
# Speed: 6.6ms preprocess, 149.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 143.9ms
# Speed: 3.2ms preprocess, 143.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 146.0ms
# Speed: 3.2ms preprocess, 146.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 142.8ms
# Speed: 3.2ms preprocess, 142.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 142.4ms
# Speed: 3.0ms preprocess, 142.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 145.5ms
# Speed: 3.6ms preprocess, 145.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 159.4ms
# Speed: 3.1ms preprocess, 159.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 137.4ms
# Speed: 4.0ms preprocess, 137.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 153.5ms
# Speed: 5.3ms preprocess, 153.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.6ms
# Speed: 3.2ms preprocess, 145.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 143.5ms
# Speed: 3.2ms preprocess, 143.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 150.9ms
# Speed: 3.2ms preprocess, 150.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 156.4ms
# Speed: 3.6ms preprocess, 156.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 157.5ms
# Speed: 3.4ms preprocess, 157.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.5ms
# Speed: 3.3ms preprocess, 146.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.5ms
# Speed: 3.4ms preprocess, 145.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.8ms
# Speed: 3.7ms preprocess, 146.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.7ms
# Speed: 3.2ms preprocess, 146.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 143.3ms
# Speed: 3.5ms preprocess, 143.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 162.5ms
# Speed: 3.2ms preprocess, 162.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.5ms
# Speed: 3.1ms preprocess, 145.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 143.3ms
# Speed: 3.2ms preprocess, 143.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.8ms
# Speed: 3.4ms preprocess, 145.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 155.8ms
# Speed: 3.3ms preprocess, 155.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 151.6ms
# Speed: 3.2ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 143.2ms
# Speed: 3.7ms preprocess, 143.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 173.14
#
# 0: 384x640 2 cars, 2 trucks, 138.1ms
# Speed: 3.4ms preprocess, 138.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.0ms
# Speed: 3.4ms preprocess, 146.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.1ms
# Speed: 3.6ms preprocess, 145.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 152.9ms
# Speed: 3.5ms preprocess, 152.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 155.6ms
# Speed: 3.8ms preprocess, 155.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 142.8ms
# Speed: 3.2ms preprocess, 142.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 140.2ms
# Speed: 3.1ms preprocess, 140.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 143.4ms
# Speed: 3.3ms preprocess, 143.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 147.1ms
# Speed: 3.3ms preprocess, 147.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 162.5ms
# Speed: 3.3ms preprocess, 162.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 147.4ms
# Speed: 4.3ms preprocess, 147.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 142.6ms
# Speed: 3.4ms preprocess, 142.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.6ms
# Speed: 3.2ms preprocess, 145.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 149.5ms
# Speed: 3.4ms preprocess, 149.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 147.7ms
# Speed: 3.7ms preprocess, 147.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 153.8ms
# Speed: 3.3ms preprocess, 153.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 144.5ms
# Speed: 3.1ms preprocess, 144.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.3ms
# Speed: 3.2ms preprocess, 145.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.7ms
# Speed: 3.4ms preprocess, 146.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 139.7ms
# Speed: 10.2ms preprocess, 139.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 157.1ms
# Speed: 5.1ms preprocess, 157.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 144.7ms
# Speed: 3.4ms preprocess, 144.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 3 trucks, 143.3ms
# Speed: 3.1ms preprocess, 143.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 3 trucks, 140.8ms
# Speed: 3.4ms preprocess, 140.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 148.0ms
# Speed: 3.2ms preprocess, 148.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 148.5ms
# Speed: 3.3ms preprocess, 148.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 160.5ms
# Speed: 3.2ms preprocess, 160.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.5ms
# Speed: 3.3ms preprocess, 146.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 213.5ms
# Speed: 4.0ms preprocess, 213.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 226.8ms
# Speed: 3.3ms preprocess, 226.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 112.91
#
# 0: 384x640 2 cars, 2 trucks, 256.2ms
# Speed: 3.1ms preprocess, 256.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 222.7ms
# Speed: 9.4ms preprocess, 222.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 229.7ms
# Speed: 3.1ms preprocess, 229.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 229.7ms
# Speed: 4.4ms preprocess, 229.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 254.6ms
# Speed: 3.2ms preprocess, 254.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 228.0ms
# Speed: 5.0ms preprocess, 228.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 238.4ms
# Speed: 3.2ms preprocess, 238.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 253.4ms
# Speed: 3.3ms preprocess, 253.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 247.6ms
# Speed: 3.2ms preprocess, 247.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 173.7ms
# Speed: 3.3ms preprocess, 173.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 144.6ms
# Speed: 3.3ms preprocess, 144.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 144.9ms
# Speed: 3.1ms preprocess, 144.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 151.7ms
# Speed: 4.2ms preprocess, 151.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 157.0ms
# Speed: 3.9ms preprocess, 157.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 144.0ms
# Speed: 3.2ms preprocess, 144.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 147.7ms
# Speed: 3.4ms preprocess, 147.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 149.2ms
# Speed: 3.5ms preprocess, 149.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 140.5ms
# Speed: 8.4ms preprocess, 140.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 156.9ms
# Speed: 3.6ms preprocess, 156.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 160.7ms
# Speed: 3.2ms preprocess, 160.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.3ms
# Speed: 3.4ms preprocess, 145.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 149.4ms
# Speed: 7.8ms preprocess, 149.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.1ms
# Speed: 3.2ms preprocess, 146.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 151.7ms
# Speed: 3.3ms preprocess, 151.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.1ms
# Speed: 5.0ms preprocess, 146.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 147.8ms
# Speed: 3.6ms preprocess, 147.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.4ms
# Speed: 3.1ms preprocess, 146.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 158.6ms
# Speed: 3.4ms preprocess, 158.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 148.9ms
# Speed: 3.3ms preprocess, 148.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 144.9ms
# Speed: 8.1ms preprocess, 144.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 165.72
#
# 0: 384x640 2 cars, 2 trucks, 158.9ms
# Speed: 3.5ms preprocess, 158.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 150.5ms
# Speed: 3.2ms preprocess, 150.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 149.1ms
# Speed: 5.0ms preprocess, 149.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 141.6ms
# Speed: 8.1ms preprocess, 141.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 155.5ms
# Speed: 3.1ms preprocess, 155.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.3ms
# Speed: 4.2ms preprocess, 145.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 154.2ms
# Speed: 3.4ms preprocess, 154.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 142.5ms
# Speed: 3.4ms preprocess, 142.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 146.7ms
# Speed: 3.5ms preprocess, 146.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 144.8ms
# Speed: 3.6ms preprocess, 144.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 154.3ms
# Speed: 3.2ms preprocess, 154.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 146.3ms
# Speed: 3.2ms preprocess, 146.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 152.2ms
# Speed: 3.9ms preprocess, 152.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 146.5ms
# Speed: 3.6ms preprocess, 146.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 167.9ms
# Speed: 3.4ms preprocess, 167.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 151.6ms
# Speed: 4.1ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 144.2ms
# Speed: 3.1ms preprocess, 144.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 156.0ms
# Speed: 3.2ms preprocess, 156.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 147.0ms
# Speed: 3.3ms preprocess, 147.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 150.5ms
# Speed: 3.5ms preprocess, 150.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 152.6ms
# Speed: 3.2ms preprocess, 152.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 142.8ms
# Speed: 5.1ms preprocess, 142.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 145.8ms
# Speed: 3.8ms preprocess, 145.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 153.1ms
# Speed: 3.5ms preprocess, 153.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 144.1ms
# Speed: 3.4ms preprocess, 144.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 144.7ms
# Speed: 3.2ms preprocess, 144.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 147.6ms
# Speed: 3.9ms preprocess, 147.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 147.1ms
# Speed: 3.2ms preprocess, 147.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 140.2ms
# Speed: 3.9ms preprocess, 140.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 158.2ms
# Speed: 6.7ms preprocess, 158.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 157.50
#
# 0: 384x640 1 car, 3 trucks, 150.9ms
# Speed: 3.5ms preprocess, 150.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 3 trucks, 145.5ms
# Speed: 3.1ms preprocess, 145.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 146.5ms
# Speed: 5.9ms preprocess, 146.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 148.7ms
# Speed: 3.3ms preprocess, 148.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 211.1ms
# Speed: 3.5ms preprocess, 211.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 227.3ms
# Speed: 3.2ms preprocess, 227.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 225.8ms
# Speed: 3.2ms preprocess, 225.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 227.6ms
# Speed: 6.2ms preprocess, 227.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 243.0ms
# Speed: 3.1ms preprocess, 243.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 233.8ms
# Speed: 5.1ms preprocess, 233.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 239.9ms
# Speed: 3.2ms preprocess, 239.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 220.7ms
# Speed: 8.5ms preprocess, 220.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 250.0ms
# Speed: 3.5ms preprocess, 250.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 244.5ms
# Speed: 8.4ms preprocess, 244.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 230.6ms
# Speed: 7.2ms preprocess, 230.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 172.7ms
# Speed: 3.6ms preprocess, 172.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 161.2ms
# Speed: 5.5ms preprocess, 161.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 145.2ms
# Speed: 3.5ms preprocess, 145.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 146.8ms
# Speed: 3.3ms preprocess, 146.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 147.5ms
# Speed: 8.1ms preprocess, 147.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 150.1ms
# Speed: 3.5ms preprocess, 150.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 157.5ms
# Speed: 3.3ms preprocess, 157.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 153.1ms
# Speed: 3.2ms preprocess, 153.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 164.7ms
# Speed: 3.4ms preprocess, 164.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 153.1ms
# Speed: 3.3ms preprocess, 153.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 146.7ms
# Speed: 3.2ms preprocess, 146.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 149.2ms
# Speed: 3.1ms preprocess, 149.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 3 trucks, 162.8ms
# Speed: 3.9ms preprocess, 162.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 154.3ms
# Speed: 3.2ms preprocess, 154.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 151.1ms
# Speed: 3.3ms preprocess, 151.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 165.01
#
# 0: 384x640 4 cars, 2 trucks, 146.3ms
# Speed: 3.3ms preprocess, 146.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 146.4ms
# Speed: 3.2ms preprocess, 146.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 148.6ms
# Speed: 3.2ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 147.2ms
# Speed: 5.7ms preprocess, 147.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 1 fire hydrant, 159.7ms
# Speed: 3.3ms preprocess, 159.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 1 fire hydrant, 149.5ms
# Speed: 5.3ms preprocess, 149.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 1 fire hydrant, 143.7ms
# Speed: 4.8ms preprocess, 143.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 2 fire hydrants, 150.2ms
# Speed: 3.1ms preprocess, 150.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 1 fire hydrant, 160.5ms
# Speed: 3.2ms preprocess, 160.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 155.8ms
# Speed: 3.6ms preprocess, 155.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 142.3ms
# Speed: 7.2ms preprocess, 142.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 1 fire hydrant, 148.1ms
# Speed: 3.3ms preprocess, 148.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 1 fire hydrant, 147.8ms
# Speed: 3.2ms preprocess, 147.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 142.4ms
# Speed: 3.7ms preprocess, 142.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 159.9ms
# Speed: 6.9ms preprocess, 159.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 1 fire hydrant, 150.4ms
# Speed: 5.1ms preprocess, 150.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 1 fire hydrant, 146.8ms
# Speed: 3.2ms preprocess, 146.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 144.3ms
# Speed: 3.2ms preprocess, 144.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 144.1ms
# Speed: 6.1ms preprocess, 144.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 160.9ms
# Speed: 3.4ms preprocess, 160.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 2 fire hydrants, 149.6ms
# Speed: 7.8ms preprocess, 149.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 146.6ms
# Speed: 4.7ms preprocess, 146.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 1 fire hydrant, 145.8ms
# Speed: 4.0ms preprocess, 145.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 143.7ms
# Speed: 4.8ms preprocess, 143.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 1 fire hydrant, 143.1ms
# Speed: 5.7ms preprocess, 143.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 2 fire hydrants, 156.4ms
# Speed: 3.2ms preprocess, 156.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 1 fire hydrant, 149.0ms
# Speed: 5.6ms preprocess, 149.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 1 fire hydrant, 146.1ms
# Speed: 3.2ms preprocess, 146.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 1 fire hydrant, 142.4ms
# Speed: 3.6ms preprocess, 142.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 1 fire hydrant, 145.0ms
# Speed: 3.3ms preprocess, 145.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 171.43
#
# 0: 384x640 5 cars, 1 truck, 1 fire hydrant, 147.2ms
# Speed: 5.1ms preprocess, 147.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 163.1ms
# Speed: 3.8ms preprocess, 163.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 149.4ms
# Speed: 3.2ms preprocess, 149.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 146.1ms
# Speed: 3.3ms preprocess, 146.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 1 fire hydrant, 144.9ms
# Speed: 5.3ms preprocess, 144.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 2 fire hydrants, 141.5ms
# Speed: 9.6ms preprocess, 141.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 150.2ms
# Speed: 3.6ms preprocess, 150.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 168.9ms
# Speed: 3.6ms preprocess, 168.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 146.4ms
# Speed: 3.4ms preprocess, 146.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 144.4ms
# Speed: 3.3ms preprocess, 144.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 234.7ms
# Speed: 3.2ms preprocess, 234.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 218.7ms
# Speed: 6.9ms preprocess, 218.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 226.9ms
# Speed: 3.3ms preprocess, 226.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 229.4ms
# Speed: 5.6ms preprocess, 229.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 214.1ms
# Speed: 3.2ms preprocess, 214.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 226.9ms
# Speed: 3.1ms preprocess, 226.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 231.1ms
# Speed: 8.7ms preprocess, 231.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 226.1ms
# Speed: 3.1ms preprocess, 226.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 241.3ms
# Speed: 7.6ms preprocess, 241.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 250.8ms
# Speed: 9.1ms preprocess, 250.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 235.8ms
# Speed: 4.6ms preprocess, 235.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 164.2ms
# Speed: 4.2ms preprocess, 164.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 143.2ms
# Speed: 9.1ms preprocess, 143.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 165.6ms
# Speed: 3.3ms preprocess, 165.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 162.9ms
# Speed: 3.2ms preprocess, 162.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 143.8ms
# Speed: 3.2ms preprocess, 143.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 150.2ms
# Speed: 3.2ms preprocess, 150.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 143.2ms
# Speed: 3.1ms preprocess, 143.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 traffic light, 153.0ms
# Speed: 3.6ms preprocess, 153.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 145.6ms
# Speed: 3.3ms preprocess, 145.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 162.63
#
# 0: 384x640 6 cars, 1 truck, 145.6ms
# Speed: 3.2ms preprocess, 145.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 146.5ms
# Speed: 3.1ms preprocess, 146.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 149.7ms
# Speed: 3.2ms preprocess, 149.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 146.1ms
# Speed: 4.0ms preprocess, 146.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 157.8ms
# Speed: 3.3ms preprocess, 157.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 158.1ms
# Speed: 3.2ms preprocess, 158.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 146.7ms
# Speed: 3.2ms preprocess, 146.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 149.1ms
# Speed: 3.2ms preprocess, 149.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 146.7ms
# Speed: 3.2ms preprocess, 146.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 155.5ms
# Speed: 3.3ms preprocess, 155.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 1 fire hydrant, 150.0ms
# Speed: 3.2ms preprocess, 150.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 156.5ms
# Speed: 7.1ms preprocess, 156.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 144.7ms
# Speed: 4.9ms preprocess, 144.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 146.2ms
# Speed: 3.3ms preprocess, 146.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 147.6ms
# Speed: 3.2ms preprocess, 147.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 150.0ms
# Speed: 3.3ms preprocess, 150.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 149.8ms
# Speed: 3.7ms preprocess, 149.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 150.2ms
# Speed: 3.2ms preprocess, 150.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 145.4ms
# Speed: 3.2ms preprocess, 145.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 145.9ms
# Speed: 3.4ms preprocess, 145.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 155.3ms
# Speed: 3.4ms preprocess, 155.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 149.7ms
# Speed: 3.2ms preprocess, 149.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 161.5ms
# Speed: 3.2ms preprocess, 161.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 156.5ms
# Speed: 3.3ms preprocess, 156.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 145.4ms
# Speed: 10.5ms preprocess, 145.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 154.6ms
# Speed: 3.3ms preprocess, 154.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 1 fire hydrant, 152.7ms
# Speed: 9.6ms preprocess, 152.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 1 fire hydrant, 150.8ms
# Speed: 3.3ms preprocess, 150.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 155.2ms
# Speed: 3.4ms preprocess, 155.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 145.4ms
# Speed: 3.5ms preprocess, 145.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 170.12
#
# 0: 384x640 4 cars, 1 truck, 144.1ms
# Speed: 3.4ms preprocess, 144.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 156.3ms
# Speed: 3.2ms preprocess, 156.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 145.0ms
# Speed: 3.1ms preprocess, 145.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 153.6ms
# Speed: 3.8ms preprocess, 153.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 150.8ms
# Speed: 3.4ms preprocess, 150.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 1 fire hydrant, 144.4ms
# Speed: 3.3ms preprocess, 144.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 145.4ms
# Speed: 6.8ms preprocess, 145.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 1 fire hydrant, 154.3ms
# Speed: 3.3ms preprocess, 154.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 148.2ms
# Speed: 3.3ms preprocess, 148.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 156.2ms
# Speed: 3.3ms preprocess, 156.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 144.3ms
# Speed: 3.3ms preprocess, 144.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 145.0ms
# Speed: 3.4ms preprocess, 145.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 156.2ms
# Speed: 3.1ms preprocess, 156.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 148.3ms
# Speed: 3.2ms preprocess, 148.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 147.6ms
# Speed: 3.3ms preprocess, 147.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 158.0ms
# Speed: 5.0ms preprocess, 158.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 228.3ms
# Speed: 3.4ms preprocess, 228.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 232.0ms
# Speed: 8.4ms preprocess, 232.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 233.0ms
# Speed: 3.2ms preprocess, 233.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 239.6ms
# Speed: 3.4ms preprocess, 239.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 220.1ms
# Speed: 5.0ms preprocess, 220.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 2 fire hydrants, 217.9ms
# Speed: 3.2ms preprocess, 217.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 1 fire hydrant, 230.5ms
# Speed: 3.2ms preprocess, 230.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 2 fire hydrants, 243.0ms
# Speed: 3.2ms preprocess, 243.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 252.7ms
# Speed: 3.4ms preprocess, 252.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 231.7ms
# Speed: 3.3ms preprocess, 231.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 250.6ms
# Speed: 3.4ms preprocess, 250.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 196.4ms
# Speed: 7.8ms preprocess, 196.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
# Speed: 3.3ms preprocess, 252.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.9ms
# Speed: 4.4ms preprocess, 214.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 3.2ms preprocess, 149.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.5ms
# Speed: 3.4ms preprocess, 147.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.4ms
# Speed: 3.6ms preprocess, 151.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.4ms
# Speed: 3.2ms preprocess, 153.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.3ms
# Speed: 4.0ms preprocess, 146.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.2ms
# Speed: 3.2ms preprocess, 153.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.1ms
# Speed: 3.3ms preprocess, 151.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.8ms
# Speed: 3.3ms preprocess, 152.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.0ms
# Speed: 3.4ms preprocess, 158.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.4ms
# Speed: 3.3ms preprocess, 152.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.4ms
# Speed: 3.5ms preprocess, 155.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.5ms
# Speed: 3.2ms preprocess, 147.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 144.4ms
# Speed: 5.0ms preprocess, 144.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.5ms
# Speed: 3.4ms preprocess, 150.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.3ms
# Speed: 3.2ms preprocess, 158.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.2ms
# Speed: 4.8ms preprocess, 150.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 166.95
#
# 0: 384x640 (no detections), 159.2ms
# Speed: 7.0ms preprocess, 159.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 139.5ms
# Speed: 12.5ms preprocess, 139.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.1ms
# Speed: 3.3ms preprocess, 146.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.8ms
# Speed: 3.5ms preprocess, 147.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.7ms
# Speed: 3.4ms preprocess, 155.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.1ms
# Speed: 3.3ms preprocess, 155.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.8ms
# Speed: 3.3ms preprocess, 147.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.8ms
# Speed: 3.3ms preprocess, 148.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.4ms
# Speed: 5.8ms preprocess, 149.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.1ms
# Speed: 3.4ms preprocess, 161.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.8ms
# Speed: 3.3ms preprocess, 149.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.2ms
# Speed: 3.3ms preprocess, 148.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.5ms
# Speed: 8.6ms preprocess, 149.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.1ms
# Speed: 5.3ms preprocess, 154.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.9ms
# Speed: 3.7ms preprocess, 143.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.4ms
# Speed: 3.2ms preprocess, 159.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 162.7ms
# Speed: 3.4ms preprocess, 162.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 144.2ms
# Speed: 4.2ms preprocess, 144.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 141.1ms
# Speed: 8.8ms preprocess, 141.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.2ms
# Speed: 3.2ms preprocess, 152.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.8ms
# Speed: 3.5ms preprocess, 143.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.3ms
# Speed: 3.7ms preprocess, 164.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.5ms
# Speed: 3.8ms preprocess, 148.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 148.6ms
# Speed: 3.5ms preprocess, 148.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.5ms
# Speed: 3.5ms preprocess, 151.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.2ms
# Speed: 3.2ms preprocess, 146.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.0ms
# Speed: 3.2ms preprocess, 156.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.1ms
# Speed: 3.3ms preprocess, 167.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.9ms
# Speed: 3.1ms preprocess, 153.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.8ms
# Speed: 4.8ms preprocess, 147.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 166.62
#
# 0: 384x640 (no detections), 145.3ms
# Speed: 5.6ms preprocess, 145.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.9ms
# Speed: 3.2ms preprocess, 147.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.5ms
# Speed: 4.6ms preprocess, 166.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.9ms
# Speed: 3.2ms preprocess, 147.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.1ms
# Speed: 3.4ms preprocess, 143.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 141.5ms
# Speed: 3.8ms preprocess, 141.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.3ms
# Speed: 3.7ms preprocess, 158.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 232.5ms
# Speed: 4.8ms preprocess, 232.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 232.2ms
# Speed: 3.3ms preprocess, 232.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 243.0ms
# Speed: 8.2ms preprocess, 243.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.8ms
# Speed: 3.2ms preprocess, 230.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 241.6ms
# Speed: 7.1ms preprocess, 241.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 237.1ms
# Speed: 7.1ms preprocess, 237.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 240.4ms
# Speed: 3.3ms preprocess, 240.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 237.5ms
# Speed: 3.9ms preprocess, 237.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.7ms
# Speed: 3.2ms preprocess, 242.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.3ms
# Speed: 3.2ms preprocess, 242.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 243.2ms
# Speed: 3.2ms preprocess, 243.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 212.5ms
# Speed: 3.2ms preprocess, 212.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.1ms
# Speed: 3.3ms preprocess, 146.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.3ms
# Speed: 3.3ms preprocess, 147.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.2ms
# Speed: 3.2ms preprocess, 147.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.8ms
# Speed: 9.2ms preprocess, 149.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.3ms
# Speed: 8.0ms preprocess, 160.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.8ms
# Speed: 3.4ms preprocess, 143.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 3.3ms preprocess, 149.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.6ms
# Speed: 8.6ms preprocess, 143.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.5ms
# Speed: 3.5ms preprocess, 146.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 141.6ms
# Speed: 5.1ms preprocess, 141.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 171.54
#
# 0: 384x640 (no detections), 156.2ms
# Speed: 3.4ms preprocess, 156.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.4ms
# Speed: 3.4ms preprocess, 146.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 3.2ms preprocess, 149.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.7ms
# Speed: 3.3ms preprocess, 149.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.3ms
# Speed: 3.2ms preprocess, 147.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.9ms
# Speed: 3.2ms preprocess, 146.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.6ms
# Speed: 3.3ms preprocess, 146.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 150.2ms
# Speed: 4.7ms preprocess, 150.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 148.6ms
# Speed: 3.3ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 150.2ms
# Speed: 3.3ms preprocess, 150.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 146.4ms
# Speed: 3.1ms preprocess, 146.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.6ms
# Speed: 3.5ms preprocess, 159.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 146.7ms
# Speed: 3.3ms preprocess, 146.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 149.0ms
# Speed: 3.3ms preprocess, 149.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 147.1ms
# Speed: 3.3ms preprocess, 147.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.8ms
# Speed: 4.4ms preprocess, 158.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.0ms
# Speed: 3.5ms preprocess, 147.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.9ms
# Speed: 3.3ms preprocess, 161.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.3ms
# Speed: 3.3ms preprocess, 150.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.0ms
# Speed: 3.4ms preprocess, 143.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.2ms
# Speed: 3.3ms preprocess, 148.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.8ms
# Speed: 3.4ms preprocess, 148.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.1ms
# Speed: 3.4ms preprocess, 157.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 144.5ms
# Speed: 3.2ms preprocess, 144.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.5ms
# Speed: 3.4ms preprocess, 148.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 150.1ms
# Speed: 3.2ms preprocess, 150.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.8ms
# Speed: 3.3ms preprocess, 154.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.0ms
# Speed: 3.2ms preprocess, 151.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.6ms
# Speed: 3.3ms preprocess, 159.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.0ms
# Speed: 3.3ms preprocess, 148.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# FPS: 164.55
#
# 0: 384x640 (no detections), 150.0ms
# Speed: 3.3ms preprocess, 150.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.5ms
# Speed: 3.3ms preprocess, 155.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.5ms
# Speed: 3.2ms preprocess, 148.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.6ms
# Speed: 3.3ms preprocess, 148.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.4ms
# Speed: 3.2ms preprocess, 157.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.7ms
# Speed: 4.2ms preprocess, 155.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.7ms
# Speed: 3.6ms preprocess, 146.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.7ms
# Speed: 3.5ms preprocess, 151.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.2ms
# Speed: 3.9ms preprocess, 147.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.9ms
# Speed: 3.6ms preprocess, 156.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.9ms
# Speed: 3.1ms preprocess, 148.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
import cv2
import numpy as np
import torch
from ultralytics import YOLO
from collections import deque
from concurrent.futures import ThreadPoolExecutor
from scipy.spatial import distance
import time

class SpeedDetector:
    def __init__(self, fps, scale_factor=0.05, smoothing_factor=0.4):
        self.fps = fps
        self.scale_factor = scale_factor  # pixels to meters
        self.alpha = smoothing_factor
        self.prev_gray = None
        self.smoothed_speeds = {}
        self.prev_centers = {}

    def calculate_speed(self, frame, detection_data):
        if self.prev_gray is None:
            self.prev_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            return 0

        current_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        x1, y1, x2, y2 = detection_data['bbox']
        obj_id = detection_data['id']

        # Crop regions for optical flow
        prev_gray_crop = self.prev_gray[y1:y2, x1:x2]
        current_gray_crop = current_gray[y1:y2, x1:x2]

        if prev_gray_crop.shape[0] > 1 and prev_gray_crop.shape[1] > 1:
            # Calculate optical flow
            flow = cv2.calcOpticalFlowFarneback(
                prev_gray_crop,
                current_gray_crop,
                None,
                0.5, 3, 15, 3, 5, 1.2, 0
            )

            # Calculate magnitude
            mag = np.sqrt(flow[..., 0]**2 + flow[..., 1]**2)
            avg_motion = np.mean(mag)

            # Convert to km/h
            dt = 1 / self.fps
            speed_mps = (avg_motion * self.scale_factor) / dt
            speed_kmph = speed_mps * 3.6

            # Apply smoothing
            if obj_id not in self.smoothed_speeds:
                self.smoothed_speeds[obj_id] = speed_kmph
            else:
                self.smoothed_speeds[obj_id] = (
                    self.alpha * speed_kmph +
                    (1 - self.alpha) * self.smoothed_speeds[obj_id]
                )

        self.prev_gray = current_gray
        return self.smoothed_speeds.get(obj_id, 0)

class LaneDetector:
    def __init__(self):
        self.prev_left_line = None
        self.prev_right_line = None
        self.left_lines_history = deque(maxlen=5)
        self.right_lines_history = deque(maxlen=5)

    def detect_lane(self, image):
        height, width = image.shape[:2]

        # Convert to HSV and create lane marking mask
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # Optimize thresholds for lane detection
        white_mask = cv2.inRange(
            hsv,
            np.array([0, 0, 200]),
            np.array([180, 30, 255])
        )
        yellow_mask = cv2.inRange(
            hsv,
            np.array([20, 100, 100]),
            np.array([30, 255, 255])
        )

        mask = cv2.bitwise_or(white_mask, yellow_mask)
        edges = cv2.Canny(mask, 50, 150)

        # Define ROI polygon
        roi_vertices = np.array([
            [(0, height),
             (width * 0.35, height * 0.5),
             (width * 0.65, height * 0.5),
             (width, height)]
        ], dtype=np.int32)

        # Apply ROI mask
        roi_mask = np.zeros_like(edges)
        cv2.fillPoly(roi_mask, roi_vertices, 255)
        masked_edges = cv2.bitwise_and(edges, roi_mask)

        # Detect lines
        lines = cv2.HoughLinesP(
            masked_edges,
            rho=1,
            theta=np.pi/180,
            threshold=20,
            minLineLength=30,
            maxLineGap=50
        )

        left_lines, right_lines = [], []
        if lines is not None:
            for line in lines:
                x1, y1, x2, y2 = line[0]
                if x2 - x1 == 0:
                    continue

                slope = (y2 - y1) / (x2 - x1)
                if abs(slope) < 0.3 or abs(slope) > 2.0:
                    continue

                if slope < 0:
                    left_lines.append(line[0])
                else:
                    right_lines.append(line[0])

        # Process lines
        left_line = self._process_lane_lines(left_lines, height, True)
        right_line = self._process_lane_lines(right_lines, height, False)

        # Update history
        if left_line is not None:
            self.left_lines_history.append(left_line)
        if right_line is not None:
            self.right_lines_history.append(right_line)

        # Get smoothed lines
        left_line = self._get_smoothed_line(self.left_lines_history)
        right_line = self._get_smoothed_line(self.right_lines_history)

        # Calculate lane info
        lane_center = width // 2
        lane_width = width // 2

        if left_line is not None and right_line is not None:
            lane_center = (left_line[0] + right_line[0]) // 2
            lane_width = right_line[0] - left_line[0]

        return lane_center, lane_width, left_line, right_line

    def _process_lane_lines(self, lines, height, is_left):
        if not lines:
            return self.prev_left_line if is_left else self.prev_right_line

        points = np.array([(x1, y1) for x1, y1, x2, y2 in lines] +
                         [(x2, y2) for x1, y1, x2, y2 in lines])

        coeffs = np.polyfit(points[:, 1], points[:, 0], deg=1)

        y_bottom = height
        y_top = int(height * 0.5)
        x_bottom = int(coeffs[0] * y_bottom + coeffs[1])
        x_top = int(coeffs[0] * y_top + coeffs[1])

        line = [x_bottom, y_bottom, x_top, y_top]

        if is_left:
            self.prev_left_line = line
        else:
            self.prev_right_line = line

        return line

    def _get_smoothed_line(self, line_history):
        if not line_history:
            return None
        return np.mean(list(line_history), axis=0, dtype=np.int32)

class RiskAssessor:
    def __init__(self):
        self.vehicle_history = {}
        self.risk_threshold_close = 50
        self.risk_threshold_speed = 15

    def calculate_risk(self, vehicle_data, lane_center, lane_width, frame_time):
        vehicle_id = vehicle_data['id']
        vehicle_x = vehicle_data['center_x']
        vehicle_y = vehicle_data['center_y']
        vehicle_speed = vehicle_data.get('speed', 0)

        if vehicle_id in self.vehicle_history:
            prev_data = self.vehicle_history[vehicle_id]
            dx = vehicle_x - prev_data['x']
            dy = vehicle_y - prev_data['y']
            dt = frame_time - prev_data['time']

            # Calculate risk factors
            speed_factor = min(1.0, vehicle_speed / 50.0)  # Normalized speed
            proximity_factor = min(1.0, (lane_width - abs(vehicle_x - lane_center)) / self.risk_threshold_close)
            lane_invasion = abs(vehicle_x - lane_center) < (lane_width * 0.4)

            # Calculate risk score
            risk_score = (
                speed_factor * 0.4 +
                proximity_factor * 0.3 +
                float(lane_invasion) * 0.3
            )

            risk_level = "SAFE"
            if risk_score > 0.7:
                risk_level = "DANGER"
            elif risk_score > 0.4:
                risk_level = "WARNING"

        else:
            risk_level = "SAFE"
            risk_score = 0

        # Update history
        self.vehicle_history[vehicle_id] = {
            'x': vehicle_x,
            'y': vehicle_y,
            'time': frame_time,
            'speed': vehicle_speed
        }

        return risk_level, risk_score

def process_frame(frame, model, lane_detector, speed_detector, risk_assessor, frame_time):
    # Resize frame
    frame = cv2.resize(frame, (1280, 720))
    with ThreadPoolExecutor(max_workers=2) as executor:
        lane_future = executor.submit(lane_detector.detect_lane, frame)
        yolo_future = executor.submit(model, frame, verbose=False)

        # Get results
        lane_center, lane_width, left_line, right_line = lane_future.result()
        results = yolo_future.result()

    # Draw lane overlay
    if left_line is not None and right_line is not None:
        overlay = frame.copy()
        cv2.fillPoly(overlay, [np.array([
            [left_line[0], left_line[1]],
            [left_line[2], left_line[3]],
            [right_line[2], right_line[3]],
            [right_line[0], right_line[1]]
        ])], (0, 255, 0, 128))
        cv2.addWeighted(overlay, 0.35, frame, 0.65, 0, frame)

    # Process detections
    for result in results:
        for box in result.boxes:
            cls = int(box.cls[0])
            conf = float(box.conf[0])

            if conf >= 0.5:
                x1, y1, x2, y2 = map(int, box.xyxy[0])

                # Calculate speed using optical flow
                detection_data = {
                    'id': f"{cls}_{x1}_{y1}",
                    'bbox': (x1, y1, x2, y2),
                    'center_x': (x1 + x2) // 2,
                    'center_y': (y1 + y2) // 2
                }

                speed = speed_detector.calculate_speed(frame, detection_data)
                detection_data['speed'] = speed

                # Calculate risk
                risk_level, risk_score = risk_assessor.calculate_risk(
                    detection_data, lane_center, lane_width, frame_time
                )

                # Draw bounding box and information
                color = {
                    "SAFE": (0, 255, 0),
                    "WARNING": (0, 255, 255),
                    "DANGER": (0, 0, 255)
                }[risk_level]

                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

                # Display information
                info_text = [
                    f"ID: {detection_data['id']}",
                    f"Speed: {speed:.1f} km/h",
                    f"Risk: {risk_level}",
                    f"Score: {risk_score:.2f}"
                ]

                for i, text in enumerate(info_text):
                    y_offset = y1 - 10 - (i * 15)
                    cv2.putText(frame, text, (x1, y_offset),
                              cv2.FONT_HERSHEY_SIMPLEX, 0.4, color, 1)

    return frame

def process_video(input_path, output_path):
    # Initialize components
    model = YOLO('yolov8n.pt')
    if torch.cuda.is_available():
        model.to('cuda')

    cap = cv2.VideoCapture(input_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Initialize components
    lane_detector = LaneDetector()
    speed_detector = SpeedDetector(fps)
    risk_assessor = RiskAssessor()

    # Setup video writer
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, fps, (1280, 720))

    frame_count = 0
    start_time = time.time()

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        current_time = time.time()

        # Process frame
        processed_frame = process_frame(
            frame,
            model,
            lane_detector,
            speed_detector,
            risk_assessor,
            current_time
        )
        out.write(processed_frame)
        if frame_count % 30 == 0:
            fps_calc = 30 / (time.time() - start_time)
            print(f"FPS: {fps_calc:.2f}")
            start_time = time.time()

    cap.release()
    out.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    input_path = '/content/lane.mp4'
    output_path = 'exp4.mp4'
    process_video(input_path, output_path)
# Out:
# FPS: 4.07
# FPS: 5.10
# FPS: 3.97
# FPS: 5.31
# FPS: 4.15
# FPS: 4.69
# FPS: 3.56
# FPS: 4.68
# FPS: 4.40
# FPS: 5.42
# FPS: 4.42
# FPS: 5.20
# FPS: 4.23
# FPS: 4.64
# FPS: 3.71
# FPS: 4.35
# FPS: 4.06
# FPS: 5.62
# FPS: 4.50
# FPS: 5.61
# FPS: 4.48
# FPS: 5.48
# FPS: 4.82
# FPS: 4.88
# FPS: 4.92
# FPS: 4.35
# FPS: 4.41
# FPS: 4.30
# FPS: 4.23
# FPS: 4.41
# FPS: 4.10
# FPS: 4.80
# FPS: 4.31
# FPS: 4.99
# FPS: 5.01
# FPS: 4.75
# FPS: 5.55
# FPS: 4.45
# FPS: 5.39
# FPS: 4.44
# FPS: 5.45
# FPS: 4.36
# FPS: 5.32
# FPS: 4.34
# FPS: 5.41
# FPS: 4.53
# FPS: 5.14
# FPS: 4.60
# FPS: 4.58
# FPS: 4.50
# FPS: 4.28
# FPS: 4.29
# FPS: 4.82
# FPS: 4.83
# FPS: 4.62
# FPS: 4.74
# FPS: 4.05
# FPS: 4.66
# FPS: 4.30
# FPS: 3.96
# FPS: 4.94
# FPS: 4.74
# FPS: 4.74
# FPS: 4.71
# FPS: 4.31
# FPS: 4.48
# FPS: 4.33
# FPS: 4.28
# FPS: 4.31
# FPS: 3.83
# FPS: 4.58
# FPS: 3.83
# FPS: 4.64
# FPS: 4.01
# FPS: 5.15
# FPS: 4.45
# FPS: 5.82
# FPS: 5.10
# FPS: 5.12
# FPS: 5.65

# %%
import cv2
import numpy as np
import torch
from ultralytics import YOLO
from collections import deque
from concurrent.futures import ThreadPoolExecutor
from scipy.spatial import distance
import time

class accDetector:
    def __init__(self, fps, scale_factor=0.05, smoothing_factor=0.4):
        self.fps = fps
        self.scale_factor = scale_factor  # pixels to meters
        self.alpha = smoothing_factor
        self.prev_gray = None
        self.smoothed_accs = {}
        self.prev_centers = {}

    def calculate_acc(self, frame, detection_data):
        if self.prev_gray is None:
            self.prev_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            return 0

        current_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        x1, y1, x2, y2 = detection_data['bbox']
        obj_id = detection_data['id']

        # Crop regions for optical flow
        prev_gray_crop = self.prev_gray[y1:y2, x1:x2]
        current_gray_crop = current_gray[y1:y2, x1:x2]

        if prev_gray_crop.shape[0] > 1 and prev_gray_crop.shape[1] > 1:
            # Calculate optical flow
            flow = cv2.calcOpticalFlowFarneback(
                prev_gray_crop,
                current_gray_crop,
                None,
                0.5, 3, 15, 3, 5, 1.2, 0
            )

            # Calculate magnitude
            mag = np.sqrt(flow[..., 0]**2 + flow[..., 1]**2)
            avg_motion = np.mean(mag)

            # Convert to km/h
            dt = 1 / self.fps
            acc_mps = (avg_motion * self.scale_factor) / dt
            acc_kmph = acc_mps * 3.6

            # Apply smoothing
            if obj_id not in self.smoothed_accs:
                self.smoothed_accs[obj_id] = acc_kmph
            else:
                self.smoothed_accs[obj_id] = (
                    self.alpha * acc_kmph +
                    (1 - self.alpha) * self.smoothed_accs[obj_id]
                )

        self.prev_gray = current_gray
        return self.smoothed_accs.get(obj_id, 0)

class LaneDetector:
    def __init__(self):
        self.prev_left_line = None
        self.prev_right_line = None
        self.left_lines_history = deque(maxlen=5)
        self.right_lines_history = deque(maxlen=5)

    def detect_lane(self, image):
        height, width = image.shape[:2]

        # Convert to HSV and create lane marking mask
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # Optimize thresholds for lane detection
        white_mask = cv2.inRange(
            hsv,
            np.array([0, 0, 200]),
            np.array([180, 30, 255])
        )
        yellow_mask = cv2.inRange(
            hsv,
            np.array([20, 100, 100]),
            np.array([30, 255, 255])
        )

        mask = cv2.bitwise_or(white_mask, yellow_mask)
        edges = cv2.Canny(mask, 50, 150)

        # Define ROI polygon
        roi_vertices = np.array([
            [(0, height),
             (width * 0.35, height * 0.5),
             (width * 0.65, height * 0.5),
             (width, height)]
        ], dtype=np.int32)

        # Apply ROI mask
        roi_mask = np.zeros_like(edges)
        cv2.fillPoly(roi_mask, roi_vertices, 255)
        masked_edges = cv2.bitwise_and(edges, roi_mask)

        # Detect lines
        lines = cv2.HoughLinesP(
            masked_edges,
            rho=1,
            theta=np.pi/180,
            threshold=20,
            minLineLength=30,
            maxLineGap=50
        )

        left_lines, right_lines = [], []
        if lines is not None:
            for line in lines:
                x1, y1, x2, y2 = line[0]
                if x2 - x1 == 0:
                    continue

                slope = (y2 - y1) / (x2 - x1)
                if abs(slope) < 0.3 or abs(slope) > 2.0:
                    continue

                if slope < 0:
                    left_lines.append(line[0])
                else:
                    right_lines.append(line[0])

        # Process lines
        left_line = self._process_lane_lines(left_lines, height, True)
        right_line = self._process_lane_lines(right_lines, height, False)

        # Update history
        if left_line is not None:
            self.left_lines_history.append(left_line)
        if right_line is not None:
            self.right_lines_history.append(right_line)

        # Get smoothed lines
        left_line = self._get_smoothed_line(self.left_lines_history)
        right_line = self._get_smoothed_line(self.right_lines_history)

        # Calculate lane info
        lane_center = width // 2
        lane_width = width // 2

        if left_line is not None and right_line is not None:
            lane_center = (left_line[0] + right_line[0]) // 2
            lane_width = right_line[0] - left_line[0]

        return lane_center, lane_width, left_line, right_line

    def _process_lane_lines(self, lines, height, is_left):
        if not lines:
            return self.prev_left_line if is_left else self.prev_right_line

        points = np.array([(x1, y1) for x1, y1, x2, y2 in lines] +
                         [(x2, y2) for x1, y1, x2, y2 in lines])

        coeffs = np.polyfit(points[:, 1], points[:, 0], deg=1)

        y_bottom = height
        y_top = int(height * 0.5)
        x_bottom = int(coeffs[0] * y_bottom + coeffs[1])
        x_top = int(coeffs[0] * y_top + coeffs[1])

        line = [x_bottom, y_bottom, x_top, y_top]

        if is_left:
            self.prev_left_line = line
        else:
            self.prev_right_line = line

        return line

    def _get_smoothed_line(self, line_history):
        if not line_history:
            return None
        return np.mean(list(line_history), axis=0, dtype=np.int32)

class RiskAssessor:
    def __init__(self):
        self.vehicle_history = {}
        self.risk_threshold_close = 50
        self.risk_threshold_acc = 15

    def calculate_risk(self, vehicle_data, lane_center, lane_width, frame_time):
        vehicle_id = vehicle_data['id']
        vehicle_x = vehicle_data['center_x']
        vehicle_y = vehicle_data['center_y']
        vehicle_acc = vehicle_data.get('acc', 0)

        if vehicle_id in self.vehicle_history:
            prev_data = self.vehicle_history[vehicle_id]
            dx = vehicle_x - prev_data['x']
            dy = vehicle_y - prev_data['y']
            dt = frame_time - prev_data['time']

            # Calculate risk factors
            acc_factor = min(1.0, vehicle_acc / 50.0)  # Normalized acc
            proximity_factor = min(1.0, (lane_width - abs(vehicle_x - lane_center)) / self.risk_threshold_close)
            lane_invasion = abs(vehicle_x - lane_center) < (lane_width * 0.4)

            # Calculate risk score
            risk_score = (
                acc_factor * 0.5 +
                proximity_factor * 0.4 +
                float(lane_invasion) * 0.1
            )

            risk_level = "SAFE"
            if risk_score > 0.7:
                risk_level = "DANGER"
            elif risk_score > 0.4:
                risk_level = "WARNING"

        else:
            risk_level = "SAFE"
            risk_score = 0

        # Update history
        self.vehicle_history[vehicle_id] = {
            'x': vehicle_x,
            'y': vehicle_y,
            'time': frame_time,
            'acc': vehicle_acc
        }

        return risk_level, risk_score

def process_frame(frame, model, lane_detector, acc_detector, risk_assessor, frame_time):
    # Resize frame
    frame = cv2.resize(frame, (1280, 720))
    with ThreadPoolExecutor(max_workers=2) as executor:
        lane_future = executor.submit(lane_detector.detect_lane, frame)
        yolo_future = executor.submit(model, frame, verbose=False)

        # Get results
        lane_center, lane_width, left_line, right_line = lane_future.result()
        results = yolo_future.result()

    # Draw lane overlay
    if left_line is not None and right_line is not None:
        overlay = frame.copy()
        cv2.fillPoly(overlay, [np.array([
            [left_line[0], left_line[1]],
            [left_line[2], left_line[3]],
            [right_line[2], right_line[3]],
            [right_line[0], right_line[1]]
        ])], (0, 255, 0, 128))
        cv2.addWeighted(overlay, 0.35, frame, 0.65, 0, frame)

    # Process detections
    for result in results:
        for box in result.boxes:
            cls = int(box.cls[0])
            conf = float(box.conf[0])

            if conf >= 0.5:
                x1, y1, x2, y2 = map(int, box.xyxy[0])

                # Calculate acc using optical flow
                detection_data = {
                    'id': f"{cls}_{x1}_{y1}",
                    'bbox': (x1, y1, x2, y2),
                    'center_x': (x1 + x2) // 2,
                    'center_y': (y1 + y2) // 2
                }

                acc = acc_detector.calculate_acc(frame, detection_data)
                detection_data['acc'] = acc

                # Calculate risk
                risk_level, risk_score = risk_assessor.calculate_risk(
                    detection_data, lane_center, lane_width, frame_time
                )

                # Draw bounding box and information
                color = {
                    "SAFE": (0, 255, 0),
                    "WARNING": (0, 255, 255),
                    "DANGER": (0, 0, 255)
                }[risk_level]

                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

                # Display information
                info_text = [
                    f"ID: {detection_data['id']}",
                    f"acc: {acc:.1f} km/h",
                    f"Risk: {risk_level}",
                    f"Score: {risk_score:.2f}"
                ]

                for i, text in enumerate(info_text):
                    y_offset = y1 - 10 - (i * 15)
                    cv2.putText(frame, text, (x1, y_offset),
                              cv2.FONT_HERSHEY_SIMPLEX, 0.4, color, 1)

    return frame

def process_video(input_path, output_path):
    # Initialize components
    model = YOLO('yolov8n.pt')
    if torch.cuda.is_available():
        model.to('cuda')

    cap = cv2.VideoCapture(input_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Initialize components
    lane_detector = LaneDetector()
    acc_detector = accDetector(fps)
    risk_assessor = RiskAssessor()

    # Setup video writer
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, fps, (1280, 720))

    frame_count = 0
    start_time = time.time()

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        current_time = time.time()

        # Process frame
        processed_frame = process_frame(
            frame,
            model,
            lane_detector,
            acc_detector,
            risk_assessor,
            current_time
        )
        out.write(processed_frame)
        if frame_count % 30 == 0:
            fps_calc = 30 / (time.time() - start_time)
            print(f"FPS: {fps_calc:.2f}")
            start_time = time.time()

    cap.release()
    out.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    input_path = '/content/youtube_video.mp4'
    output_path = 'youtube_output.mp4'
    process_video(input_path, output_path)
# Out:
# FPS: 5.41
# FPS: 4.34
# FPS: 4.16
# FPS: 2.33
# FPS: 3.38
# FPS: 2.65
# FPS: 4.10
# FPS: 4.20
# FPS: 5.20
# FPS: 4.85
# FPS: 6.11
# FPS: 5.38
# FPS: 5.30
# FPS: 4.65
# FPS: 3.57
# FPS: 3.52
# FPS: 3.87
# FPS: 3.37

# %%
# !pip install -q yt_dlp
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 39.7 MB/s eta 0:00:00

# %%
import yt_dlp

# YouTube Shorts URL
video_url = "https://www.youtube.com/shorts/R-sw3lKb974"

# Download settings
ydl_opts = {
    "format": "mp4",
    "outtmpl": "youtube_video.mp4",  # Output filename
}

# Download video
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([video_url])

print("Download complete")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/R-sw3lKb974
# [youtube] R-sw3lKb974: Downloading webpage
# [youtube] R-sw3lKb974: Downloading tv client config
# [youtube] R-sw3lKb974: Downloading player 9c6dfc4a
# [youtube] R-sw3lKb974: Downloading tv player API JSON
# [youtube] R-sw3lKb974: Downloading ios player API JSON
# [youtube] R-sw3lKb974: Downloading m3u8 information
# [info] R-sw3lKb974: Downloading 1 format(s): 18
# [download] Destination: youtube_video.mp4
# [download] 100% of    1.09MiB in 00:00:00 at 2.50MiB/s
# Download complete
